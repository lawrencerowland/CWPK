# %% [markdown]
# CWPK \#19: Exploring the API to OWL
# =======================================
#
# Let's Get Familiar with Some Basic owlready2 Commands
# --------------------------
#
# <div style="float: left; width: 305px; margin-right: 10px;">
#
# <img src="http://kbpedia.org/cwpk-files/cooking-with-kbpedia-305.png" title="Cooking with KBpedia" width="305" />
#
# </div>
#
# In our last installment of this [*Cooking with Python and
# KBpedia*](https://www.mkbergman.com/cooking-with-python-and-kbpedia/) series, we learned some KBpedia terminology and loaded the main [KBpedia](https://kbpedia.org/) knowledge graph file, <code>kbpedia_reference_concepts.owl</code>. (Remember, do **NOT** use the <code>kbpedia_reference_concepts.n3</code> since [owlready2](http://www.lesfleursdunormal.fr/static/informatique/owlready/index_en.html) does not support the [Notation3](https://en.wikipedia.org/wiki/Notation3) syntax.) You will need to navigate back to that file location again. One of the aspects of working with [Jupyter Notebook](https://en.wikipedia.org/wiki/Project_Jupyter) is that, once you leave the application, you must re-load your files again whenever you return to the application. As you also recall, it is also necessary to Run the cells in order for a given notebook to restore the states that each cell needs.
#
# In today's installment we will start to get familiar with some basic commands in owlready2, the [API](https://en.wikipedia.org/wiki/Application_programming_interface) to our [OWL2](https://en.wikipedia.org/wiki/Web_Ontology_Language) [ontologies](https://en.wikipedia.org/wiki/Upper_ontology). We will then apply these basic approaches to starting efforts to manage these ontologies, which begins with our next installment.

# %% [markdown]
# ### Load and Import the Ontologies
#
# <div style="background-color:#eee; border:1px dotted #aaa; vertical-align:middle; margin:15px 60px; padding:8px;"><strong>Which environment?</strong> The specific load routine you should choose below depends on whether you are using the online MyBinder service (the 'raw' version) or local files. See <a href="https://www.mkbergman.com/2347/cwpk-17-choosing-and-installing-an-owl-api/"><strong>CWPK #17</strong></a> for further details.</div>
#
# #### Local File Option
# As we instructed in the last installment, the best practice is to provide names to absolute file addresses to make sure you are getting and loading the files you need. Again, in this instance, we call name this file <code>main</code> and we also add some code to verify the file was found by listing its contents:

# %%
main = '/Users/lawrence/Documents/GitHub/CWPK/sandbox/builds/ontologies/kbpedia_reference_concepts.owl'

# %%
with open(main) as fobj:                           
    for line in fobj:
        print (line)

# %% [markdown]
# After you <code>shift+enter</code> to execute the cell contents, or pick Run from the main menu, you will see a rather long file listing. To clear it from the screen, run Cell &rarr; All Output &rarr; Clear.
#
# The KBpedia full ontology also depends on ('imports') two other files: the KBpedia upper ontology, KKO (<code>kko.owl</code>), and the SKOS language that we use for annotations (<code>http://www.w3.org/2004/02/skos/core</code>). As we described in the prior **CWPK** installment, you will need to [download the raw version](https://raw.githubusercontent.com/Cognonto/CWPK/master/sandbox/builds/ontologies/kko.owl) of <code>kko.owl</code>, and store it in the same location as <code>kbpedia_reference_concepts.owl</code> downloaded in the prior installment. There is no need to download the <code>skos</code> file.
#
# Again, we give names to their absolute file addresses, only this time we do not echo their file listings to screen:

# %%
kko_file = r'/Users/lawrence/Documents/GitHub/CWPK/sandbox/builds/ontologies/kko.owl'

# %%
skos_file = 'http://www.w3.org/2004/02/skos/core#'

# %% [markdown]
# Note one file (<code>kko</code>) is on disk and we use the native Windows file path (with backward slashes) by invoking the '<code>r</code>' (raw) command switch: <code>r'C:\1-PythonProjects\kbpedia\sandbox\kko.owl'</code>. The other <code>skos</code> file is found off of the Web.
#
# #### MyBinder Option
# If you are running this notebook online, do **NOT** run the above routines, since the load routines vary somewhat. Please use the following instructions.

# %%
main = 'https://raw.githubusercontent.com/Cognonto/CWPK/master/sandbox/builds/ontologies/kbpedia_reference_concepts.owl'

# %% [markdown]
# To view this file, run the next cell, otherwise, run the following cells to load all graphs.

# %%
import urllib.request 

for line in urllib.request.urlopen(main):
    print(line.decode('utf-8'), end='')

# %%
kko_file = 'https://raw.githubusercontent.com/Cognonto/CWPK/master/sandbox/builds/ontologies/kko.owl'

# %%
skos_file = 'http://www.w3.org/2004/02/skos/core'

# %% [markdown]
# ### Begin the Import
# Now that our three files have been given logical names, we are ready to import them into our Jupyter Notebook. Run each of these cells (<code>shift+enter</code>) in sequence:

# %%
from owlready2 import *
onto = get_ontology(main).load()

# %%
import urllib.request

# %% [markdown]
# The asterisk (\*) after the import statement means that we want to load all modules in the owlready2 package. One of those functions is <code>get_ontology</code>. We have also given our main ontology the name of <code>onto</code>

# %%
skos = get_ontology(skos_file).load()

# %%
onto.imported_ontologies.append(skos)

# %%
kko = get_ontology(kko_file).load()
onto.imported_ontologies.append(kko)

# %% [markdown]
# We can also place all three commands into a single cell. Note, however, that if you run this consolidated command, that you will see double listings when you invoke <code>print(onto.imported_ontologies)</code> below. In other words, while there is no harm to loading a file again, you are better off only doing the consolidated alone or the three separate loads alone.
#
# You can run the command below to see this behavior. You should then log off or Kernal &rarr; Restart & Clear Output and then only load one set before proceeding further.

# %%
from owlready2 import *
onto = get_ontology(main).load()

skos = get_ontology(skos_file).load()
onto.imported_ontologies.append(skos) 

kko = get_ontology(kko_file).load()
onto.imported_ontologies.append(kko)

# %% [markdown]
# Let's now test to make sure the ontologies have been loaded OK by checking to see if the base IRIs for all graphs are recognized by the system:

# %%
print(onto.base_iri)
# Out:
# http://kbpedia.org/kbpedia/rc#

# %%
print(skos.base_iri)
# Out:
# http://www.w3.org/2004/02/skos/core#

# %%
print(kko.base_iri)
# Out:
# http://kbpedia.org/ontologies/kko#

# %% [markdown]
# We can also confirm that the two additional ontologies have been properly imported:

# %%
print(onto.imported_ontologies)
# Out:
# [get_ontology("http://www.w3.org/2004/02/skos/core#"), get_ontology("http://kbpedia.org/ontologies/kko#")]

# %% [markdown]
# ### Inspecting Ontology Contents
#
# We can now start checking to see if the components of the ontologies have loaded properly. Let's first check on the classes:

# %%
list(onto.classes())
# Out:
# [rc.A-10Thunderbolt,
#  rc.FighterAttackPlane,
#  rc.A-GenerationalCephalosporin,
#  rc.Antibacterial,
#  rc.AAAI,
#  rc.LearnedSociety,
#  rc.ResearchOrganization,
#  rc.AASM,
#  rc.Weapon-PrecisionArmament,
#  rc.AB-205-Helicopter,
#  rc.Helicopter,
#  rc.ABSResin,
#  rc.Thermoplastic,
#  rc.ACAcecaCar,
#  rc.EnglishCar,
#  rc.ACEInhibitor,
#  rc.AntihypertensiveDrug,
#  rc.Cilazapril,
#  rc.Delapril,
#  rc.Fosinopril,
#  rc.Imidapril,
#  rc.ACFRiverBasin,
#  rc.DrainageBasin,
#  rc.ACPowerPlugSocket,
#  rc.ElectricalConnector,
#  rc.ACappella,
#  rc.Singing,
#  rc.ADHDBiology,
#  rc.AttentionDeficitHyperactivityDisorder,
#  rc.AEASilverDart,
#  rc.Biplane,
#  rc.AEWAircraft,
#  rc.AirborneEarlyWarningAircraft,
#  rc.AFC-West-Football,
#  rc.NationalFootballLeagueDivision,
#  rc.AGPBusProtocol,
#  rc.MachineProtocol,
#  rc.AGS-17,
#  rc.GrenadeLauncher-Portable,
#  rc.AI-Planning,
#  rc.ScientificFieldOfStudy,
#  rc.AIDS,
#  rc.HIVInfection,
#  rc.LifeThreateningCondition,
#  HIV.AIDSinMalawi,
#  rc.AIDSClinic,
#  rc.MedicalClinic,
#  rc.AIDSDementiaComplex,
#  rc.PsychologicalAilment,
#  rc.AIDSDrugCocktail,
#  rc.DrugCocktail,
#  rc.HAARTDrugCocktail,
#  rc.AIDSSpecialist,
#  rc.Doctor-Medical,
#  rc.AIMk.IvRadar,
#  rc.AircraftRadar,
#  rc.AIResearchDepartment,
#  rc.ComputerScienceDepartment,
#  rc.ResearchAndDevelopmentDepartment,
#  rc.TechnologyOrganization,
#  rc.AK-74,
#  rc.AssaultRifle,
#  rc.AMAMotocrossChampionship,
#  rc.ChampionshipCompetition,
#  rc.AMCConcordCar,
#  rc.AmericanMotors,
#  rc.AMCGremlin,
#  rc.AMGenCar,
#  rc.AmericanAutomobile,
#  rc.Humvee,
#  rc.AMState,
#  rc.Device-On,
#  rc.AutoAMRadio,
#  rc.AMX-30,
#  rc.Tank-Vehicle,
#  rc.ANFO,
#  rc.HighExplosive,
#  rc.Mixture,
#  rc.ANTPQ-37Firefinder,
#  rc.CounterArtilleryRADAR,
#  rc.ANZUS,
#  rc.InternationalOrganizationOfCountries,
#  rc.APECSummit,
#  rc.AsiaPacificEconomicCooperation,
#  rc.APriori,
#  rc.Justification,
#  rc.AR-15,
#  rc.Rifle,
#  rc.ARMArchitecture,
#  rc.ComputerTypeByArchitecture,
#  rc.ASCII,
#  rc.CommunicationProtocol,
#  rc.ASCII-Art,
#  rc.DigitalArtObject,
#  rc.ASEAN,
#  rc.AssociationOfSoutheastAsianNationsLaw,
#  rc.AssociationOfSoutheastAsianNationsMeeting,
#  rc.MemberState-ASEAN,
#  rc.ASN1SyntaxSpecification,
#  rc.FormalMetaGrammar,
#  rc.ASPAccountingSystem,
#  rc.AccountingProgram,
#  rc.ATFAgent,
#  rc.LawEnforcementOfficer,
#  rc.ATPTennisTournament,
#  rc.TennisTournament,
#  rc.ATR42,
#  rc.AircraftTypeByBrand,
#  rc.ATR72,
#  rc.ATSC,
#  rc.HDTVSet,
#  rc.ATandTComputer,
#  rc.PersonalComputer,
#  rc.AVIFile,
#  rc.ComputerVideoFile,
#  rc.AVMediaProduct,
#  rc.MediaProduct,
#  rc.AVMediaSeriesProduct,
#  rc.BroadcastMediaProduct,
#  rc.ComicStrip,
#  rc.Movie,
#  rc.RecordedVideoProduct,
#  rc.VideoRecordedObject,
#  rc.MediaSeriesProduct,
#  rc.BroadcastSeriesProduct,
#  rc.MovieSeriesProduct,
#  rc.AWACSAircraft,
#  rc.BoeingE-3Sentry,
#  rc.AZT,
#  rc.NucleosideReverseTrancriptaseInhibitor,
#  rc.AaptosKanuux,
#  rc.Porifera,
#  rc.Aardwolf,
#  rc.Hyena,
#  rc.Quadruped,
#  rc.Aargau,
#  rc.Canton-Swiss,
#  rc.Aaron,
#  rc.Exodus-BookOfBible,
#  rc.AaronCopland-Composer,
#  rc.MusicalComposer,
#  rc.Aba-Garment,
#  rc.OuterGarment,
#  rc.AbaCloth,
#  rc.Cloth,
#  rc.Abacavir,
#  rc.Ziagen,
#  rc.AbadanRefinery,
#  rc.OilRefinery,
#  rc.Abandoned-ConstructionArtifact,
#  rc.ConstructionArtifactStatus,
#  rc.FacetInstanceCollection,
#  rc.AbandonedHamlet,
#  rc.AbandonedVillage,
#  rc.FormerRailwayStation,
#  rc.GhostTown,
#  rc.AbandonwareProgram,
#  rc.ComputerProgram,
#  rc.AbaremaOxyphyllidia,
#  rc.Legume-ThePlant,
#  rc.Abatis,
#  rc.ManMadeObstacle,
#  rc.AbbasidCaliphate,
#  rc.SunniIslam,
#  rc.Abbey,
#  rc.ReligiousBuilding,
#  rc.ReligiousResidence,
#  rc.CapuchinFriary,
#  rc.Convent-Residence,
#  rc.AbbotsOfIona,
#  rc.Cleric,
#  rc.Abbreviation,
#  rc.ProperNameString,
#  rc.Acronym,
#  rc.Abdicating,
#  rc.ChangeOfStatusEvent,
#  rc.OrganizationalTransferOut,
#  rc.Apostasy,
#  rc.Abdication,
#  rc.Monarchy,
#  rc.Abdomen,
#  rc.AnimalBodyPart,
#  rc.ExternalAnatomicalPart,
#  rc.ColonAnatomy,
#  rc.Spleen,
#  rc.AbdominalAorta,
#  rc.Artery,
#  rc.SystemicArtery,
#  rc.AbdominalCavity,
#  rc.CavityWithWalls,
#  rc.InternalAnatomicalPart,
#  rc.AbdominalExerciseDevice,
#  rc.ExerciseEquipment,
#  rc.AbdominalPain,
#  rc.Ache-AilmentCondition,
#  rc.Pain-PhysiologicalCondition,
#  rc.AbdominalSurgeon,
#  rc.Surgeon,
#  rc.Abdopus,
#  rc.Octopus,
#  rc.AbducensNerve,
#  rc.CranialNerve,
#  rc.MotorNerve,
#  rc.AbductiveInferenceProcess,
#  rc.Reasoning,
#  rc.FramingSocialSciences,
#  rc.Hypothesis,
#  rc.Theories,
#  rc.AbductorDigitiMinimi,
#  rc.SkeletalMuscle,
#  rc.AbductorPollicisBrevis,
#  rc.AbductorPollicisLongus,
#  rc.AbelianGroupTheory,
#  rc.GroupTheory,
#  rc.AbelsonMurineLeukemiaVirus,
#  rc.Gammaretrovirus,
#  rc.AberdeenProvingGround,
#  rc.ProvingGround,
#  rc.Abhorrence,
#  rc.Disgust,
#  rc.EmotionalQuantityType,
#  rc.Hate,
#  rc.AbigailVanBuren,
#  rc.Fictional-FemaleHuman,
#  rc.Abiu,
#  rc.FruitTree,
#  rc.AbkhazLanguage,
#  rc.LivingLanguage,
#  rc.Abkhazia,
#  rc.Caucasus-Region,
#  rc.AbkhazianPeople,
#  rc.PersonTypeByNationality,
#  rc.Ablation,
#  rc.PurposefulPhysicalAction,
#  rc.RemovingSomething,
#  rc.Separation-Complete,
#  rc.AbleBodiedSeaman,
#  rc.CrewMemberOnShip,
#  rc.Abnormal-Organism-Whole,
#  rc.Abnormal-Unusual,
#  rc.Organism,
#  rc.Mutant,
#  rc.AbnormalSystemCondition,
#  rc.AnomalousSituation,
#  rc.Experimental,
#  rc.FloodedArea,
#  rc.Miracle,
#  rc.SnowProcess,
#  rc.AbnormalBehaviourInAnimals,
#  rc.Ethology,
#  rc.AbnormalRespiration,
#  rc.Respiration,
#  rc.Situation-Localized,
#  rc.MidlifeCrisis,
#  rc.PhysiologicalCondition,
#  rc.AboBat,
#  rc.Pipistrellus,
#  rc.Abolitionism,
#  rc.PoliticalBeliefSystem,
#  rc.AbolitionismByCountry,
#  rc.AbolitionistMovement,
#  rc.Abolitionist,
#  rc.PersonTypeByBeliefSystem,
#  rc.FreeLabor,
#  rc.AbominableSnowman,
#  rc.Biped,
#  rc.CoveredWithHair,
#  rc.LegendaryCreature,
#  rc.Mammal,
#  rc.SentientAnimal,
#  rc.AboriginalTitle,
#  rc.CommonLawSystem,
#  rc.AboriginesInTasmania,
#  rc.TasmaniaIslandAustralia,
#  rc.Abortifacient,
#  rc.DrugSubstance,
#  rc.Misoprostol,
#  rc.Oxytocic,
#  rc.Abortion-BreastCancerHypothesis,
#  rc.AbortionDebate,
#  rc.Abortion-Intentional,
#  rc.BiologicalDestructionEvent,
#  rc.IntelligentAgentActivity,
#  rc.MedicalTreatmentEvent,
#  rc.ForcedAbortion,
#  rc.MethodsOfAbortion,
#  rc.SocialIssue,
#  rc.AbortionProvider,
#  rc.MedicalCareProvider,
#  rc.AboutPage,
#  rc.WebPage,
#  rc.AboveGround,
#  rc.Place-Generic,
#  rc.AbqaiqOilField,
#  rc.OilField,
#  rc.Abra-ProvincePhilippines,
#  rc.Province-Philippines,
#  rc.Abraham-Patriarch,
#  rc.Patriarch,
#  rc.AbrahamLincoln,
#  rc.Lawyer,
#  rc.UnitedStatesPresident,
#  rc.Abralia,
#  rc.Enoploteuthidae,
#  rc.Abrasive,
#  rc.CoatingsAdhesive,
#  rc.GrindingPolishingMaterial,
#  rc.Rough,
#  rc.AbrasiveMesh,
#  rc.EmeryBoard,
#  rc.AbrasiveBlasting,
#  rc.Metalworking,
#  rc.AbrasiveWheel,
#  rc.TungstenCarbideAbrasiveWheel,
#  rc.AbrinToxin,
#  rc.BiologicalToxin,
#  rc.Powder,
#  rc.AbscisicAcid,
#  rc.Phytohormone,
#  rc.Absinthe,
#  rc.BitterTaste,
#  rc.GreenColor,
#  rc.IllegalDrug,
#  rc.Liquor-Drink,
#  rc.AbsolutVodka,
#  rc.Vodka,
#  rc.AbsoluteMonarchy,
#  rc.AbsoluteSportsEvent,
#  rc.MeasuredSportsEvent,
#  rc.RacingSportsEvent,
#  rc.TrackAndField,
#  rc.WeightliftingSportsEvent,
#  rc.AbsoluteZero,
#  rc.Temperature,
#  rc.AbsorbableGelatinSponge,
#  rc.ExogenousTopicalHemostaticAgent,
#  rc.Absorbency,
#  rc.DispositionalQuantity,
#  rc.TangiblePhysicalQuantity,
#  rc.TotallyOrderedQuantityType,
#  rc.Absorbent,
#  rc.CleaningJanitorialSupply,
#  rc.AbsorptionEvent,
#  rc.TransferIn,
#  rc.Abstinence,
#  rc.Inaction,
#  rc.Abstract,
#  rc.Document,
#  rc.TextualPCWStructure,
#  rc.AbstractAlgebra,
#  rc.Algebra,
#  rc.AbstractInformationStructure,
#  rc.AbstractStructure,
#  rc.AtomicSymbol-Abstract,
#  rc.CWInfoStructure,
#  rc.ComputerAIS,
#  rc.GraphicalAIS,
#  rc.LexicalItem,
#  rc.NumericString,
#  rc.RelationalStructure,
#  rc.SententialConstituent,
#  rc.AbstractManagementSoftware,
#  rc.BusinessComputerProgram,
#  rc.AbstractObjectTheory,
#  rc.PhilosophyBeliefs,
#  rc.AbstractProgrammingLanguage,
#  rc.ComputerLanguage,
#  rc.Ada-ProgrammingLanguage,
#  rc.Awk-ProgrammingLanguage,
#  rc.Basic-ComputerLanguage,
#  rc.C-ProgrammingLanguage,
#  rc.CPlusPlus-ProgrammingLanguage,
#  rc.Cobol,
#  rc.CycL,
#  rc.Fortran,
#  rc.JavaScriptProgrammingLanguage,
#  rc.LOGO-ProgrammingLanguage,
#  rc.PHP-ProgrammingLanguage,
#  rc.Pascal-ProgrammingLanguage,
#  rc.Perl-ProgrammingLanguage,
#  rc.ProgrammingLanguage-Lisp,
#  rc.Prolog-ComputerLanguage,
#  rc.Python-ProgrammingLanguage,
#  rc.SubL,
#  rc.Tcl-ProgrammingLanguage,
#  rc.VisualBasic,
#  rc.VisualCPlusPlus-ProgrammingLanguage,
#  rc.AbstractVisualStructure,
#  rc.CWStructure,
#  rc.ContextualizedInformationStructure,
#  rc.Hierarchy,
#  rc.GraphicalStructure,
#  rc.AbuDhabi,
#  rc.CapitalCityOfRegion,
#  rc.Abuse,
#  rc.ViolentAction,
#  rc.AnimalAbuse,
#  rc.ChildAbuse,
#  rc.HumanRightsAbuse,
#  rc.IncestualAbuse,
#  rc.PsychologicalAbuse,
#  rc.SatanicRitualAbuse,
#  rc.SexualAbuse,
#  rc.AbutilonEremitopetalum,
#  rc.Mallow,
#  rc.AbutilonSandwicense,
#  rc.AbyssalPlain,
#  rc.UnderwaterTopographicalFeature,
#  rc.Abyssinian-Cat,
#  rc.DomesticCat,
#  rc.AbyssinianWoodpecker,
#  rc.Woodpecker,
#  rc.Acacia,
#  rc.LegumeOrder,
#  rc.Plant-Woody,
#  rc.Academia,
#  rc.Education,
#  rc.AcademicBookReport,
#  rc.AcademicComposition,
#  rc.NonfictionalPCW,
#  rc.TextualPCW,
#  rc.AcademicEssay,
#  rc.BookReport,
#  rc.AcademicCycles-TimeTopic,
#  rc.Time-Topic,
#  rc.AcademicDepartment,
#  rc.AcademicOrganization,
#  rc.UniversityDepartment,
#  rc.AgricultureDepartment,
#  rc.AnthropologyDepartment,
#  rc.BiologyDepartment,
#  rc.BotanyDepartment,
#  rc.ChemistryDepartment,
#  rc.ClassicsDepartment,
#  rc.EconomicsDepartment,
#  rc.EngineeringAcademicDepartment,
#  rc.HistoryDepartment,
#  rc.LinguisticsDepartment,
#  rc.MathematicsDepartment,
#  rc.PhilosophyDepartment,
#  rc.PhysicsDepartment,
#  rc.PsychologyDepartment,
#  rc.ZoologyDepartment,
#  rc.AcademicDepartmentTypeBySubject,
#  rc.AcademicDressByInstitution,
#  rc.AcademicGown,
#  rc.Essay,
#  rc.AcademicGenealogies,
#  rc.Genealogy,
#  rc.ClothingOutfit,
#  rc.OverGarment,
#  rc.Robe,
#  rc.AcademicInstitution,
#  rc.AcademicJournal,
#  rc.ScholarlyArticle,
#  rc.ScientificJournal,
#  rc.EducationalOrganization,
#  rc.ElementarySchool,
#  rc.HigherEducationInstitution,
#  rc.KindergartenInstitution,
#  rc.School-AcademicOrganization,
#  rc.SchoolInstitution-KThrough12,
#  rc.Seminary,
#  rc.AcademicProfessional,
#  rc.LiterateAgent,
#  rc.Researcher,
#  rc.SkilledWorker,
#  rc.CulturalAcademic,
#  rc.Historian,
#  rc.Professor,
#  rc.Teacher,
#  rc.AcademicQuarter,
#  rc.AcademicTerm,
#  rc.AcademicSemester,
#  rc.UniversitySemester,
#  rc.AcademicStudiesOfRitualAndMagic,
#  rc.MagicSpell,
#  rc.Ritual,
#  rc.AcademicStudiesOfShamanism,
#  rc.Shamanism,
#  rc.AcademicStyleGuide,
#  rc.CalendarSeason,
#  rc.AcademicTrimester,
#  rc.AcademicYear,
#  rc.AcademicTest,
#  rc.AcademicTesting,
#  rc.PerformanceTesting,
#  rc.Test-Assessment,
#  rc.UniversityEntryTest,
#  rc.AcademicYear-American,
#  rc.AcademicsAndWritersOnBullying,
#  rc.Bullying,
#  rc.AcademicsAndWritersOnNarcissism,
#  rc.Narcissism,
#  rc.Academy,
#  rc.RoyalGalicianAcademy,
#  rc.RussianAcademy,
#  rc.AcademyAward,
#  rc.AwardAttribute,
#  rc.FilmAward,
#  rc.AcademyAwardForBestActor-Movie,
#  rc.AcademyAwardForBestActress-Movie,
#  rc.AcademyAwardForBestSupportingActor-Movie,
#  rc.AcademyAwardWinner,
#  rc.BestAnimatedShortFilm-MotionPicture,
#  rc.BestArtDirection-MotionPicture,
#  rc.BestCinematography-MotionPicture,
#  rc.BestCostumeDesign-MotionPicture,
#  rc.BestDirector-MotionPicture,
#  rc.BestDocumentaryFeature-MotionPicture,
#  rc.BestDocumentaryShortSubject-MotionPicture,
#  rc.BestFilmEditing-MotionPicture,
#  rc.BestForeignLanguageFilm-MotionPicture,
#  rc.BestLiveActionShortFilm-MotionPicture,
#  rc.BestMakeup-MotionPicture,
#  rc.BestMotionPictureOriginalMusicalOrComedyScore,
#  rc.BestOriginalScreenplay-MotionPicture,
#  rc.BestOriginalSong-MotionPicture,
#  rc.BestPicture-MotionPicture,
#  rc.BestScreenplayAdaptation-MotionPicture,
#  rc.BestSoundEffectsEditing-MotionPicture,
#  rc.BestSoundRecording-MotionPicture,
#  rc.BestSupportingActressMovieAcademyAward,
#  rc.BestVisualEffects-MotionPicture,
#  rc.MotionPictureAwardCategory,
#  rc.AcademyAwardCategory,
#  rc.FirstOrderCollection,
#  rc.AcademyAwardsLists,
#  rc.Winner,
#  rc.AcademyAwardsCeremony,
#  rc.AwardsCeremony,
#  rc.AcademyMuseumOfMotionPictures,
#  rc.AcademyOfMotionPictureArtsAndSciences,
#  rc.ProfessionalAssociation,
#  rc.AcadiaNationalPark,
#  rc.NationalPark,
#  rc.Acalyptratae,
#  rc.Fly-Insect,
#  rc.Acanthite,
#  rc.Mineral,
#  rc.AcanthobrahmaeaEuropaea,
#  rc.Moth,
#  rc.Acanthocalycium,
#  rc.Cactus,
#  rc.Acanthocercus,
#  rc.Agamidae,
#  rc.Acanthocereus,
#  rc.AcanthocheilonemaViteae,
#  rc.Nematode,
#  rc.Acanthodactylus,
#  rc.Lacertidae,
#  rc.Acanthomintha,
#  rc.MintFamily,
#  rc.AcanthominthaDuttonii,
#  rc.Acanthopelminae,
#  rc.Tarantula,
#  rc.Acanthophoenix,
#  rc.PalmTree,
#  rc.Acanthopteroctetidae,
#  rc.Acanthostachys,
#  rc.Bromelioideae,
#  rc.Acarina,
#  rc.Arachnid,
#  rc.Mite,
#  rc.Tick,
#  rc.Acartophthalmidae,
#  rc.Accelerating,
#  rc.MovementEvent,
#  rc.Accelerating-Translational,
#  rc.Movement-TranslationProcess,
#  rc.Flipping,
#  rc.Acceleration,
#  rc.PhysicalQuantity,
#  rc.Rate,
#  rc.ThreeDimensionalQuantity,
#  rc.AccelerationClause,
#  rc.Obligation,
#  rc.AccelerationVibrationMeasuringInstrument,
#  rc.MeasuringTestingInstrument,
#  rc.AcceleratorMassSpectrometry,
#  rc.MassSpectrometry,
#  rc.Accelerometer,
#  rc.Gauge,
#  rc.Transducer,
#  rc.AccentFurniture,
#  rc.Furniture,
#  rc.Vitrine,
#  rc.Accepted,
#  rc.Proposal,
#  rc.Accepting-CommunicationAct,
#  rc.Acknowledging-CommunicationAct,
#  rc.Approval-CommunicationAct,
#  rc.AcceptingAnInvitation,
#  rc.ApprovingARequest,
#  rc.AccessCorridor,
#  rc.Path-Customary,
#  rc.AccessManagementService,
#  rc.InformationTechnologyServiceDelivery,
#  rc.AccessNumber,
#  rc.PhoneNumber,
#  rc.Accessibility,
#  rc.Design,
#  rc.AccessibleInformation,
#  rc.InformationScience,
#  rc.AccessingAFile,
#  rc.AccessingAnIBT,
#  rc.FileOperation,
#  rc.InformationTransferPhysicalEvent,
#  rc.AccessingAFile-ReadOnly,
#  rc.DownloadingAFile,
#  rc.SavingAFile,
#  rc.CopyingAComputerFile,
#  rc.InformationTransferEvent,
#  rc.IntelligenceActivity,
#  rc.Eavesdropping,
#  rc.ListeningDeliberately,
#  rc.PalmReading,
#  rc.Reading,
#  rc.TarotReading,
#  rc.WebBrowsing,
#  rc.Accessory-Artifact,
#  rc.ArtificialPhysicalObject,
#  rc.Audio-Accessory,
#  rc.Desk-Accessory,
#  rc.IndoorGrill-Accessory,
#  rc.Motorcycle-Accessory,
#  rc.Wedding-Accessory,
#  rc.Wireless-Accessory,
#  rc.AccessoryFruit,
#  rc.Fruit,
#  rc.Strawberry,
#  rc.AccessoryHemiAzygosVein,
#  rc.SystemicVein,
#  rc.AccessoryMuscle,
#  rc.MuscularSystem,
#  rc.AccessoryNerve,
#  rc.Accident,
#  rc.EndangeringSomething,
#  rc.PhysicalEvent,
#  rc.FallingDown,
#  rc.LocomotionAccident,
#  rc.OilSpill,
#  rc.Oversleeping,
#  rc.PipelineAccident,
#  rc.ThreeMileIslandAccident,
#  rc.TitanicSinking,
#  rc.VehicleAccident,
#  rc.AccidentInvolvingDouglasC47Skytrain,
#  rc.AirplaneCrash,
#  rc.AccidentInvolvingEurostar,
#  rc.Eurostar,
#  rc.AccidentInvolvingMilitaryAircraft,
#  rc.AccidentInvolvingRoyalAirForceAircraft,
#  rc.AccidentInvolvingTheAirbusA320,
#  rc.AccidentInvolvingTheAirbusA321,
#  rc.AccidentInvolvingTheAirbusA380,
#  rc.AccidentInvolvingTheBoeing727,
#  rc.AccidentInvolvingTheBoeing747,
#  rc.AccidentInvolvingTheBoeing757,
#  rc.AccidentInvolvingTheBoeing767,
#  rc.AccidentInvolvingTheBoeing777,
#  rc.AccidentInvolvingTheBoeing787,
#  rc.AccidentInvolvingTheDouglasDC3,
#  rc.Accipiter,
#  rc.Accipitrinae,
#  rc.BirdOfPrey,
#  rc.Leucopternis,
#  rc.Milvinae,
#  rc.AccipitrineFamily,
#  rc.FalconiformOrder,
#  rc.Aegypiinae,
#  rc.Aviceda,
#  rc.BaldEagle,
#  rc.Black-and-whiteHawk-eagle,
#  rc.Butastur,
#  rc.Buteoninae,
#  rc.Circaetinae,
#  rc.Dryotriorchis,
#  rc.Eagle,
#  rc.Elaninae,
#  rc.Erythrotriorchis,
#  rc.Geranoaetus,
#  rc.HarpagusBird,
#  rc.HarriersBird,
#  rc.Hawk,
#  rc.Henicopernis,
#  rc.Hieraaetus,
#  rc.Melierax,
#  rc.Osprey,
#  rc.Perninae,
#  rc.Accommodating-HelpingAnAgent,
#  rc.HelpingAnAgent,
#  rc.AccommodationBuildingStructure,
#  rc.PermanentBuildingStructure,
#  rc.AslyumBuilding,
#  rc.DayCareCenter,
#  rc.FlatApartment,
#  rc.HotelRoom,
#  rc.ResidentialHome,
#  rc.AccommodationFurniture,
#  rc.BabyToddlerFurniture,
#  rc.GeneralFurniturePartAccessory,
#  rc.HomeFurniture,
#  rc.OfficeFurniture,
#  rc.OutdoorFurniture,
#  rc.OutdoorFurnitureMarketCategory,
#  rc.AccomplishmentType,
#  rc.ProcessingEvent,
#  rc.MorphologicalProcess,
#  rc.TransformationalProcessType,
#  rc.Accordion,
#  rc.Keyboard-MusicalInstrument,
#  rc.MusicalInstrument,
#  rc.Concertina,
#  rc.Accordionist,
#  rc.MusicalInstrumentPlayer,
#  rc.Account-LegalAgreement,
#  rc.AuthorizedAgreement,
#  rc.BusinessActivity,
#  rc.EconomicAgreement,
#  rc.AccountActive,
#  rc.AccountInactive,
#  rc.AccountPending,
#  rc.AccountSystemTypeByImplementationMeans,
#  rc.AgreementForOngoingService,
#  rc.AgreementForService,
#  rc.CustodialAccount,
#  rc.EMailAccount,
#  rc.EquityMortgage,
#  rc.FHATitleILoanAgreement,
#  rc.FinancialAccount,
#  rc.InComplianceWithPaymentSchedule,
#  rc.InstitutionalAccount,
#  rc.InternetService,
#  rc.MarketingAccount,
#  rc.NomineeAccount,
#  rc.PaymentOverdue,
#  rc.PersonalAccount,
#  rc.SalesAccount,
#  rc.WorkAccount,
#  rc.AccountTypeByStatus,
#  rc.AccountBasedCreditProduct,
#  rc.BankOfferedProduct,
#  rc.AutomotiveLoan,
#  rc.HomeEquityLoan,
#  rc.MortgageLoan,
#  rc.UnsecuredLoan,
#  rc.AccountManager,
#  rc.Administrator,
#  rc.BusinessPerson,
#  rc.Manager,
#  rc.AccountOperatorAccount,
#  rc.PrivilegedAccount,
#  rc.AccountSystem,
#  rc.ComputationalSystem,
#  rc.NTAccountSystem,
#  rc.AccountType,
#  rc.TemporalStuffType,
#  rc.BankAccount,
#  rc.CreditAccount,
#  rc.ExpenseAccount,
#  rc.RetirementAccount,
#  rc.TaxDeferredAccount,
#  rc.Accountant,
#  rc.DeskWorker,
#  rc.Professional,
#  rc.Auditor,
#  rc.CertifiedPublicAccountant,
#  rc.Accounting,
#  rc.CodeOfConduct,
#  rc.AccountingBookkeepingService,
#  rc.FinancialInsuranceService,
#  rc.AccountingService,
#  rc.AuditService,
#  rc.CorporateFinance,
#  rc.TaxationIssuePreparation,
#  rc.AccountingClerk,
#  rc.AccountingDepartment,
#  rc.FinanceDepartment,
#  rc.AccountsPayableDepartment,
#  rc.AccountsReceivableDepartment,
#  rc.BursarsOffice,
#  rc.AccountingEnterpriseResourcePlanningSoftware,
#  rc.Software,
#  rc.FinancialAnalysisSoftware,
#  rc.TaxSoftware,
#  rc.AccountingFirm,
#  rc.CommercialServiceOrganization,
#  rc.FinancialOrganization,
#  rc.PrivateSectorOrganization,
#  rc.ProfessionalServiceOrganization,
#  rc.FinancialProgram,
#  rc.AccountingSoftwareForLinux,
#  rc.FreeAccountingSoftware,
#  rc.AccountingReport,
#  rc.FinancialDocument,
#  rc.AuditTrail,
#  rc.BalanceSheet,
#  rc.GeneralLedger-Document,
#  rc.AccountingScandal,
#  rc.Fraud,
#  rc.BookkeepingService,
#  rc.FinancialAccountingService,
#  rc.TaxAccountingService,
#  rc.AccountingSoftwareMaintenance,
#  rc.SoftwareMaintenanceSupport,
#  rc.AccountingUse,
#  rc.Computer,
#  rc.AccountsPayableWorker,
#  rc.Accreditation,
#  rc.Credential,
#  rc.AccreditationEvent,
#  rc.AccruingInterest,
#  rc.IncreasingTheBalanceOnAnAccount,
#  rc.AccumulatingSteadily,
#  rc.IntrinsicStateChangeEvent,
#  rc.Accumulation-Profits,
#  rc.Profits,
#  rc.Accuracy,
#  rc.Ambiguity,
#  rc.Accusing,
#  rc.AttributingResponsibility,
#  rc.HostileSocialAction,
#  rc.Blame,
#  rc.MakingACriminalCharge,
#  rc.Acebrochol,
#  rc.Steroid,
#  rc.Acebutolol,
#  rc.BetaBlocker,
#  rc.Aceh,
#  rc.SumatraIsland-Indonesia,
#  rc.AcerComputer,
#  rc.AceramarcaGracileOpossum,
#  rc.Opossum,
#  rc.Acetabulum,
#  rc.BoneSubPart,
#  rc.Acetamide,
#  rc.Plasticizer,
#  rc.Acetaminophen,
#  rc.Analgesic,
#  rc.Antipyretic,
#  rc.Solid-StateOfMatter,
#  rc.AcetaminophenProduct,
#  rc.OverTheCounterDrug,
#  rc.TylenolAcetaminophenProduct,
#  rc.Acetate,
#  rc.OrganicCompound,
#  rc.Salt-ChemicalSubstance,
#  rc.AluminiumAcetate,
#  rc.AmmoniumAcetate,
#  rc.AmylAcetate,
#  rc.AntimonyIIIAcetate,
#  rc.BenzylAcetate,
#  rc.ButylAcetate,
#  rc.CaesiumAcetate,
#  rc.CalciumAcetate,
#  rc.CelluloseAcetate,
#  rc.ChromiumIIAcetate,
#  rc.CopperIIAcetate,
#  rc.EthylAcetate,
#  rc.GeranylAcetate,
#  rc.HeptylAcetate,
#  rc.IronIIAcetate,
#  rc.IsobutylAcetate,
#  rc.IsopropylAcetate,
#  rc.LeadIIAcetate,
#  rc.ManganeseIIIAcetate,
#  rc.MercuryIIAcetate,
#  rc.MethylAcetate,
#  rc.SilverAcetate,
#  rc.SodiumAcetate,
#  rc.TriethylammoniumAcetate,
#  rc.UranylAcetate,
#  rc.UranylZincAcetate,
#  rc.ZincAcetate,
#  rc.12-O-Tetradecanoylphorbol-13-acetate,
#  rc.AcetateIon,
#  rc.PolyatomicAnion,
#  rc.AcetateRelated,
#  rc.Antihistamine,
#  rc.AceticAcid,
#  rc.CarboxylicAcid,
#  rc.Liquid-StateOfMatter,
#  rc.Transparent,
#  rc.WeakElectrolyte,
#  rc.AceticAnhydride,
#  rc.AcidAnhydride,
#  rc.Acetivibrio,
#  rc.Clostridiaceae-Family,
#  rc.Acetone,
#  rc.Ketone,
#  rc.ToxicSubstance,
#  rc.AcetoneCyanohydrin,
#  rc.Cyanohydrin,
#  rc.AcetylChloride,
#  rc.AcylHalide,
#  rc.LachrymationInducingStuff,
#  rc.AcetylCoenzymeA,
#  rc.Thioester,
#  rc.Acetylcholine,
#  rc.Neuromodulator,
#  rc.Neurotransmitter,
#  rc.Anticholinergic,
#  rc.Acetylcholinesterase,
#  rc.Enzyme,
#  rc.Acetyldihydrocodeine,
#  rc.OpioidDrug,
#  rc.Acetylene,
#  rc.Alkyne,
#  rc.GaseousFuel,
#  rc.Achaea,
#  rc.PeloponnesianPeninsula,
#  rc.Achaean,
#  rc.AncientGreecePeople,
#  rc.AchaemenidArchitecture,
#  rc.ArchitecturalTypeByStyle,
#  rc.AchaemenidEgypt,
#  rc.AncientEgypt,
#  rc.AchaemenidSatrapsOfIonia,
#  rc.Ionia,
#  rc.Acharagma,
#  rc.AchariaApicalis,
#  rc.AchariaButterfly,
#  rc.AilmentCondition,
#  rc.Headache,
#  rc.AchievementTest,
#  rc.PsychologicalTesting,
#  rc.AchievingNirvana,
#  rc.SacredPractice,
#  rc.Achilles-Human,
#  rc.IndividualPeople,
#  rc.MythologicalHero,
#  rc.AchillesTendon,
#  rc.Tendon,
#  rc.AchlaenaPoaceae,
#  rc.GrassFamily,
#  rc.AchlysiellaWilliamsi,
#  rc.Achnatherum,
#  rc.AchnatherumCoronatum,
#  rc.AchnatherumRobustum,
#  rc.Acholeplasma-Genus,
#  rc.Acholeplasmataceae-Family,
#  rc.Acholeplasmatales-Order,
#  rc.Phytoplasma-Genus,
#  rc.Mollicutes-Class,
#  rc.AcholiPeople,
#  rc.EthnicGroupOfAcholi,
#  rc.Achondrite,
#  rc.Meteorite,
#  rc.Achondroplasia,
#  rc.DiseaseType,
#  rc.AchromaticColor,
#  rc.Color,
#  rc.BlackColor,
#  rc.GrayColor,
#  rc.PureWhiteColor,
#  rc.FunctionalGroup-Molecular,
#  rc.AcidCatalyst,
#  rc.Catalyst,
#  rc.AcidDye,
#  rc.Dye,
#  rc.AcidFreeTissuePaper,
#  rc.TissuePaper,
#  rc.AcidHouse,
#  rc.Rave-DanceParty,
#  rc.AcidIndigestion,
#  rc.AcidRainProcess,
#  rc.RainProcess,
#  rc.AcidType,
#  rc.AcidType-Arrhenius,
#  rc.AcidType-Bronsted-Lowry,
#  rc.AcidType-Strong,
#  rc.AcidType-Lewis,
#  rc.AcidType-Diprotic,
#  rc.AcidType-Polyprotic,
#  rc.ChemicalSubstanceType,
#  rc.AcidType-Oxyacid,
#  rc.AcidType-Weak,
#  rc.AmphotericSubstanceType,
#  rc.AcidType-Monoprotic,
#  rc.AcidType-Negligible,
#  rc.AcidbaseDisturbance,
#  rc.IntensiveCareEvent,
#  rc.AcidbasePhysiology,
#  rc.Physiology,
#  rc.AcidicSolution-Liquid,
#  rc.ChemicallyAcidicSubstance,
#  rc.LiquidSolution,
#  rc.StomachAcid,
#  rc.SulfuricAcidSolution,
#  rc.Vinegar,
#  rc.Acidifier,
#  rc.InorganicCompound,
#  rc.AcidizingEquipment,
#  rc.OilGasDrillingExplorationEquipment,
#  rc.Acidobacteria,
#  rc.Bacterium,
#  rc.Acidosasa,
#  rc.BambooPlant,
#  rc.Acinetobacter,
#  ...]

# %% [markdown]
# Now, this listing above is interesting. You will see a few warning messages at the top of the listing. This is due to the fact that a very few KBpedia RCs share the same subClasses, making them essentially equivalent classes. The ones listed here are purposeful and do no harm; generally, however, you want to avoid such duplication.
#
# Next, if you scroll down to the bottom you will see that the listing is actually truncated at the bottom with the <code>[...]</code> indicator. If you were to copy the output listing to an editor you would see there are exactly 1000 items in this list, the default limit for such listings when you first install Jupyter Python. But we know there are more than 58,000 RCs (classes) in the system. To see a complete listing we will need to make a change to our notebook's configuration file.
#
# <div style="background-color:#eee; border:1px dotted #aaa; vertical-align:middle; margin:15px 60px; padding:8px;"><strong>Note:</strong> This option does not apply to the online MyBinder version.</div>
#
# First, you need to exit this notebook and at your command line create an IPython config file if you don't already have one:
#
# <pre>ipython profile create</pre>
#
# Once generated, this config file can be found in your user's directory (<code>C:\Users\mike\.ipython\profile_default\ipython_config.py</code> in my case). Make sure and note the dot in the <code>.ipython</code> directory. Navigate to your appropriate directory and edit this config file to remove the comment for this line and to set the value to '0':
#
# <pre>c.PlainTextFormatter.max_seq_length = 0</pre>
#
# (which, again, is set to 1000 by default.)

# %% [markdown]
# Restart your notebook instance after making this change and run the cells above again. You will now see the full listing of RCs in KBpedia. (A hat tip to [StackOverflow](https://stackoverflow.com/questions/23388810/ipython-notebook-output-cell-is-truncating-contents-of-my-list) for this snippet.)
#
# But, hmmm, where are the classes from the <code>kko</code> and <code>skos</code> imports? All we are showing in this list are the RCs from the default ontology of <code>main</code>.
#
# One of the interesting aspects of owlready2 is its use of what it calls 'worlds' to isolate given items into separate namespaces. This allows different projects to be held in memory at one time, including even different open and closed reasoning that may be applied. (A topic for a later installment.)
#
# Now, it is the case that we loaded all three of our ontologies without specifying different 'world' namespaces. To see the three combined, let's actually specify the 'world' that is currently active, which is called 'default' if not otherwise specified. Rather than our previous <code>onto</code> namespace, let's now explicitly refer to this default:

# %%
list(default_world.classes())

# %% [markdown]
# Note the full IRI listings for the <code>kko</code> classes at the bottom of the listing. This signals a bit of a namespace recognition problem, that we will address in a few moments.
#
# We can use this same dot approach of <code>namespace.method</code> for other components in our system. (See **Additional Documentation** below for a listing of such methods available in owlready2.)
#
# In the two examples below we list the annotation properties for both the main (<code>onto</code>) and <code>skos</code> namespaces:

# %%
list(onto.annotation_properties())

# %%
list(skos.annotation_properties())

# %% [markdown]
# Now, one of the RCs we see in out listing is for Eutheria, the technical name for mammals. Using the same format as above we want to get a listing of its subclasses, but adding our <code>rc.</code> prefix in fact does not work:

# %%
list(rc.Eutheria.subclasses())

# %% [markdown]
# Hmmm, it is not immediately clear why we get the error that '<code>rc</code>' is not defined.
#
# If we look at the KBpedia Web site we see, in fact, that our prefix to individual RCs is actually <code>http://kbpedia.org/kko/rc/</code> with the trailing '/'. owlready2 documentation indicates it uses the '#' sign as its default separator for vocabulary terms. Since our system uses the '/', perhaps something got screwed up in how owlready2 recognizes our namespace.
#
# One way to deal with this potential problem explicitly is to make a direct assignment for what the IRI prefix should be. We do so via this command, where we are directing the prefix '<code>rc</code>' to recognize our standard base IRI:

# %%
rc = onto.get_namespace('http://kbpedia.org/kko/rc/')

# %% [markdown]
# With this new namespace assignment, we run the command again:

# %%
list(rc.Eutheria.subclasses())

# %% [markdown]
# Voilà! We now have the proper registry of the namespace in our system.
#
# Along with absolute file names that we reference via assigned names, it is also good practice to make sure that our namespaces are properly registered before beginning work with owlready2. (I may discover better tips as we move ahead that I will post when and if discovered.)
#
# We can also check out the properties for this concept:

# %%
list(rc.Eutheria.get_class_properties())

# %% [markdown]
# And, pull out our definition for the concept:

# %%
print(rc.Eutheria.definition)

# %% [markdown]
# There is also the alternate IRI sytax for identifying a class, in this case to obtain all of the children, grandchildren, etc., of our Mammal concept (which produces a long list of mammals!):

# %%
IRIS['http://kbpedia.org/kko/rc/Mammal'].descendants()

# %% [markdown]
# Since we have used the Python <code>list</code> method quite a bit, we can get direct assistance about the method with the standard command:

# %%
help(list)

# %% [markdown]
# We can also conduct searches of our RCs, including with wildcards (\*) in either the pre or post positions:

# %%
onto.search(iri = "*Luggage*")

# %% [markdown]
# Another helpful command in owlready2 is to instruct the system what paths to search when it looks for referenced names:

# %%
onto_path.append("C:/1-PythonProjects/kbpedia/sandbox")

# %% [markdown]
# And, we can get a listing of all such paths registered:

# %%
list(onto_path)

# %% [markdown]
# Lastly, for this installment, we can close by saving the ontology we have been working on, being careful in this instance to give a different file name to prevent inadvertent overwriting of our initial input file:

# %%
onto.save(file = "C:/1-PythonProjects/kbpedia/sandbox/owl-test.owl", format = "rdfxml")

# %% [markdown]
# To properly exit the notebook, first pick File &rarr; Save and Checkpoint, then File &rarr; Close and Halt. This will return you to the main Jupyter files screen, from which you Quit and then close the tab. Return to the command window and finish shutting down the service with <code>ctrl+c</code>. That will return you to the command prompt, from which you may again start up a '<code>Jupyter Notebook</code>' instance.

# %% [markdown]
# ### Additional Documentation
#
# Here is a listing of [owlready2 ontology methods](https://owlready2.readthedocs.io/en/latest/onto.html).
#
#
#  <div style="background-color:#efefff; border:1px dotted #ceceff; vertical-align:middle; margin:15px 60px; padding:8px;">
#   <span style="font-weight: bold;">NOTE:</span> This article is part of the <a href="https://www.mkbergman.com/cooking-with-python-and-kbpedia/" style="font-style: italic;">Cooking with Python and KBpedia</a> series. See the <a href="https://www.mkbergman.com/cooking-with-python-and-kbpedia/"><strong>CWPK</strong> listing</a> for other articles in the series. <a href="http://kbpedia.org/">KBpedia</a> has its own Web site.
#   </div>
#
# <div style="background-color:#ebf8e2; border:1px dotted #71c837; vertical-align:middle; margin:15px 60px; padding:8px;">
#
# <span style="font-weight: bold;">NOTE:</span> This <strong>CWPK
# installment</strong> is available both as an online interactive
# file <a href="https://mybinder.org/v2/gh/Cognonto/CWPK/master" ><img src="https://mybinder.org/badge_logo.svg" style="display:inline-block; vertical-align: middle;" /></a> or as a <a href="https://github.com/Cognonto/CWPK" title="CWPK notebook" alt="CWPK notebook">direct download</a> to use locally. Make sure and pick the correct installment number. For the online interactive option, pick the <code>*.ipynb</code> file. It may take a bit of time for the interactive option to load.</div>
#
# <div style="background-color:#feeedc; border:1px dotted #f7941d; vertical-align:middle; margin:15px 60px; padding:8px;">
# <div style="float: left; margin-right: 5px;"><img src="http://kbpedia.org/cwpk-files/warning.png" title="Caution!" width="32" /></div>I am at best an amateur with Python. There are likely more efficient methods for coding these steps than what I provide. I encourage you to experiment -- which is part of the fun of Python -- and to <a href="mailto:mike@mkbergman.com">notify me</a> should you make improvements.
#
# </div>
